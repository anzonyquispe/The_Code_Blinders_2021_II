# %%
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
region_libertad = pd.read_excel(r"C:\Users\Danny\Documents\GitHub\The_Code_Blinders_2021_II\Classes\DATA_TASK4\Region_La_Libertad.xlsx")
region_libertad
# Out:
#      Unnamed: 0       Region    District          Place  4_6_years_men  \
# 0             0  LA LIBERTAD    TRUJILLO     P.TRUJILLO            162
# 1             1  LA LIBERTAD    TRUJILLO       C.LAREDO             17
# 2             2  LA LIBERTAD    TRUJILLO  LAS HACIENDAS              6
# 3             3  LA LIBERTAD    TRUJILLO        MAMICHE              3
# 4             4  LA LIBERTAD      ASCOPE       P.ASCOPE             75
# ..          ...          ...         ...            ...            ...
# 194         194  LA LIBERTAD  CACHICADAN       HOSPITAL              0
# 195         195  LA LIBERTAD  CACHICADAN        C.CHUCA              0
# 196         196  LA LIBERTAD   MOLLEPATA    P.MOLLETAPA             17
# 197         197  LA LIBERTAD   MOLLEPATA   C.MOLLEBAMBA              8
# 198         198  LA LIBERTAD   SITABAMBA    P.SITABAMBA             29
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# ...

# %%
# Pregunta 1 Eliminar columnas innecesarias
region_libertad_2 = region_libertad.drop(columns = "Unnamed: 0")
region_libertad_2
# Out:
#           Region    District          Place  4_6_years_men  4_6_years_women  \
# 0    LA LIBERTAD    TRUJILLO     P.TRUJILLO            162              136
# 1    LA LIBERTAD    TRUJILLO       C.LAREDO             17               14
# 2    LA LIBERTAD    TRUJILLO  LAS HACIENDAS              6               10
# 3    LA LIBERTAD    TRUJILLO        MAMICHE              3               11
# 4    LA LIBERTAD      ASCOPE       P.ASCOPE             75               68
# ..           ...         ...            ...            ...              ...
# 194  LA LIBERTAD  CACHICADAN       HOSPITAL              0                0
# 195  LA LIBERTAD  CACHICADAN        C.CHUCA              0                0
# 196  LA LIBERTAD   MOLLEPATA    P.MOLLETAPA             17                4
# 197  LA LIBERTAD   MOLLEPATA   C.MOLLEBAMBA              8                2
# 198  LA LIBERTAD   SITABAMBA    P.SITABAMBA             29               27
#
# ...

# %%
# Pregunta 2 Encontrar el tipo de datos
region_libertad_2.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# ...

# %%
# Pregunta 3 Encontrar la cantidad de habitantes
region_libertad_pob = region_libertad_2[["4_6_years_total" , "6_14_years_total"]]
region_libertad_pob
region_libertad_pob.sum()
# Out:
# 4_6_years_total      4454
# 6_14_years_total    21156
# dtype: int64

# %%
# Pregunta 4 Filtrar la cantidad de habitantes del distrito "trujillo"
region_libertad_cant = region_libertad_2.loc[region_libertad_2["District"]== "TRUJILLO"]
region_libertad_cant
# Out:
#         Region  District          Place  4_6_years_men  4_6_years_women  \
# 0  LA LIBERTAD  TRUJILLO     P.TRUJILLO            162              136
# 1  LA LIBERTAD  TRUJILLO       C.LAREDO             17               14
# 2  LA LIBERTAD  TRUJILLO  LAS HACIENDAS              6               10
# 3  LA LIBERTAD  TRUJILLO        MAMICHE              3               11
#
#    4_6_years_total  6_14_years_men  6_14_years_women  6_14_years_total  \
# 0              298             823               809              1632
# 1               31              83                68               151
# 2               16              44                40                84
# 3               14              27                22                49
#
#    man_read  ...  not_finished_instr_women  not_finished_instr_total  \
# 0       580  ...                       845                      1743
# 1        53  ...                        80                       178
# ...

# %%
# Pregunta 5 Localizar la region de mayor cantidad de habitantes tanto para personas de 4 a 6 años como de 6 a 14 años
region[region['6_14_years_total']== region['6_14_years_total'].max()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-bfef16924658> in <module>
#       1 # Pregunta 5 Localizar la region de mayor cantidad de habitantes tanto para personas de 4 a 6 años como de 6 a 14 años
# ----> 2 region[region['6_14_years_total']== region['6_14_years_total'].max()]
#
# NameError: name 'region' is not defined

# %%
mystring_1 = "Hello"
print(mystring_1)
# Out:
# Hello
