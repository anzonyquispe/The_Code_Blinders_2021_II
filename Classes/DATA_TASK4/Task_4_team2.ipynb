# %% [markdown]
# # Task 4
# ### Alvaro Palma

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
La_Libertad_data = pd.read_excel(r"D:\Documentos\Python_Code_Blinders\Region_La_Libertad.xlsx")
La_Libertad_data
# Out:
#      Unnamed: 0       Region    District          Place  4_6_years_men  \
# 0             0  LA LIBERTAD    TRUJILLO     P.TRUJILLO            162
# 1             1  LA LIBERTAD    TRUJILLO       C.LAREDO             17
# 2             2  LA LIBERTAD    TRUJILLO  LAS HACIENDAS              6
# 3             3  LA LIBERTAD    TRUJILLO        MAMICHE              3
# 4             4  LA LIBERTAD      ASCOPE       P.ASCOPE             75
# ..          ...          ...         ...            ...            ...
# 194         194  LA LIBERTAD  CACHICADAN       HOSPITAL              0
# 195         195  LA LIBERTAD  CACHICADAN        C.CHUCA              0
# 196         196  LA LIBERTAD   MOLLEPATA    P.MOLLETAPA             17
# 197         197  LA LIBERTAD   MOLLEPATA   C.MOLLEBAMBA              8
# 198         198  LA LIBERTAD   SITABAMBA    P.SITABAMBA             29
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# ...

# %%
# Eliminar columnas innecesarias
La_Libertad = La_Libertad_data.drop(columns= "Unnamed: 0")
La_Libertad
# Out:
#           Region    District          Place  4_6_years_men  4_6_years_women  \
# 0    LA LIBERTAD    TRUJILLO     P.TRUJILLO            162              136
# 1    LA LIBERTAD    TRUJILLO       C.LAREDO             17               14
# 2    LA LIBERTAD    TRUJILLO  LAS HACIENDAS              6               10
# 3    LA LIBERTAD    TRUJILLO        MAMICHE              3               11
# 4    LA LIBERTAD      ASCOPE       P.ASCOPE             75               68
# ..           ...         ...            ...            ...              ...
# 194  LA LIBERTAD  CACHICADAN       HOSPITAL              0                0
# 195  LA LIBERTAD  CACHICADAN        C.CHUCA              0                0
# 196  LA LIBERTAD   MOLLEPATA    P.MOLLETAPA             17                4
# 197  LA LIBERTAD   MOLLEPATA   C.MOLLEBAMBA              8                2
# 198  LA LIBERTAD   SITABAMBA    P.SITABAMBA             29               27
#
# ...

# %%
# Encontrar tipo de datos
La_Libertad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Region                    199 non-null    object
#  1   District                  199 non-null    object
#  2   Place                     199 non-null    object
#  3   4_6_years_men             199 non-null    int64
#  4   4_6_years_women           199 non-null    int64
#  5   4_6_years_total           199 non-null    int64
#  6   6_14_years_men            199 non-null    int64
#  7   6_14_years_women          199 non-null    int64
#  8   6_14_years_total          199 non-null    int64
#  9   man_read                  199 non-null    int64
#  10  women_read                199 non-null    int64
#  11  total_read                199 non-null    int64
#  12  men_not_read              199 non-null    int64
#  13  women_not_read            199 non-null    int64
# ...

# %%
# Encontrar la cantidad de habitantes
La_Libertad_pop = La_Libertad[["4_6_years_total","6_14_years_total"]]
La_Libertad_pop
La_Libertad_pop.sum()
# Out:
# 4_6_years_total      4454
# 6_14_years_total    21156
# dtype: int64

# %%
# Filtrar la cantidad de habitantes del distrito "trujillo"
La_Libertad_cdc = La_Libertad.loc[La_Libertad["District"]== "TRUJILLO"]
La_Libertad_cdc
# Out:
#         Region  District          Place  4_6_years_men  4_6_years_women  \
# 0  LA LIBERTAD  TRUJILLO     P.TRUJILLO            162              136
# 1  LA LIBERTAD  TRUJILLO       C.LAREDO             17               14
# 2  LA LIBERTAD  TRUJILLO  LAS HACIENDAS              6               10
# 3  LA LIBERTAD  TRUJILLO        MAMICHE              3               11
#
#    4_6_years_total  6_14_years_men  6_14_years_women  6_14_years_total  \
# 0              298             823               809              1632
# 1               31              83                68               151
# 2               16              44                40                84
# 3               14              27                22                49
#
#    man_read  ...  not_finished_instr_women  not_finished_instr_total  \
# 0       580  ...                       845                      1743
# 1        53  ...                        80                       178
# ...

# %%
La_Libertad_cdc_pop = La_Libertad_cdc[["4_6_years_total","6_14_years_total"]]
La_Libertad_cdc_pop
# Out:
#    4_6_years_total  6_14_years_total
# 0              298              1632
# 1               31               151
# 2               16                84
# 3               14                49

# %%
La_Libertad_cdc_pop.sum()
# Out:
# 4_6_years_total      359
# 6_14_years_total    1916
# dtype: int64

# %%
# Localizar la region de mayor cantidad de habitantes tanto para personas de 4 a 6 años como de 6 a 14 años
La_Libertad["4_6_years_total"].idxmax()
# Out:
# 0

# %%
La_Libertad.iloc[0]
# Out:
# Region                      LA LIBERTAD
# District                       TRUJILLO
# Place                        P.TRUJILLO
# 4_6_years_men                       162
# 4_6_years_women                     136
# 4_6_years_total                     298
# 6_14_years_men                      823
# 6_14_years_women                    809
# 6_14_years_total                   1632
# man_read                            580
# women_read                          589
# total_read                         1169
# men_not_read                        405
# women_not_read                      356
# total_not_read                      761
# man_write                           398
# women_write                         402
# total_write                         800
# men_not_write                       587
# women_not_write                     543
# total_not_write                    1130
# instruction_men                     543
# instruction_women                   495
# ...

# %%
La_Libertad["6_14_years_total"].idxmax()
# Out:
# 0

# %%
La_Libertad.iloc[0]
# Out:
# Region                      LA LIBERTAD
# District                       TRUJILLO
# Place                        P.TRUJILLO
# 4_6_years_men                       162
# 4_6_years_women                     136
# 4_6_years_total                     298
# 6_14_years_men                      823
# 6_14_years_women                    809
# 6_14_years_total                   1632
# man_read                            580
# women_read                          589
# total_read                         1169
# men_not_read                        405
# women_not_read                      356
# total_not_read                      761
# man_write                           398
# women_write                         402
# total_write                         800
# men_not_write                       587
# women_not_write                     543
# total_not_write                    1130
# instruction_men                     543
# instruction_women                   495
# ...
