# %% [markdown]
# # Eliminar las columnas que crean necesaria

# %%
import pandas as pd
data=pd.read_excel(r"C:\Users\SCOTT\Downloads\Region_La_Libertad.xlsx")

# %%
data
# Out:
#      Unnamed: 0       Region    District          Place  4_6_years_men  \
# 0             0  LA LIBERTAD    TRUJILLO     P.TRUJILLO            162
# 1             1  LA LIBERTAD    TRUJILLO       C.LAREDO             17
# 2             2  LA LIBERTAD    TRUJILLO  LAS HACIENDAS              6
# 3             3  LA LIBERTAD    TRUJILLO        MAMICHE              3
# 4             4  LA LIBERTAD      ASCOPE       P.ASCOPE             75
# ..          ...          ...         ...            ...            ...
# 194         194  LA LIBERTAD  CACHICADAN       HOSPITAL              0
# 195         195  LA LIBERTAD  CACHICADAN        C.CHUCA              0
# 196         196  LA LIBERTAD   MOLLEPATA    P.MOLLETAPA             17
# 197         197  LA LIBERTAD   MOLLEPATA   C.MOLLEBAMBA              8
# 198         198  LA LIBERTAD   SITABAMBA    P.SITABAMBA             29
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# ...

# %%
la_libertad=data.drop(columns= "Unnamed: 0")
la_libertad
# Out:
#           Region    District          Place  4_6_years_men  4_6_years_women  \
# 0    LA LIBERTAD    TRUJILLO     P.TRUJILLO            162              136
# 1    LA LIBERTAD    TRUJILLO       C.LAREDO             17               14
# 2    LA LIBERTAD    TRUJILLO  LAS HACIENDAS              6               10
# 3    LA LIBERTAD    TRUJILLO        MAMICHE              3               11
# 4    LA LIBERTAD      ASCOPE       P.ASCOPE             75               68
# ..           ...         ...            ...            ...              ...
# 194  LA LIBERTAD  CACHICADAN       HOSPITAL              0                0
# 195  LA LIBERTAD  CACHICADAN        C.CHUCA              0                0
# 196  LA LIBERTAD   MOLLEPATA    P.MOLLETAPA             17                4
# 197  LA LIBERTAD   MOLLEPATA   C.MOLLEBAMBA              8                2
# 198  LA LIBERTAD   SITABAMBA    P.SITABAMBA             29               27
#
# ...

# %% [markdown]
# # Encontrar el tipo de datos

# %%
data.dtypes
# Out:
# Unnamed: 0                   int64
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# ...

# %%
la_libertad.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# ...

# %% [markdown]
# # Encontrar la cantidad de habitantes

# %%
cant_hab = la_libertad[['4_6_years_total','6_14_years_total']]
cant_hab
# Out:
#      4_6_years_total  6_14_years_total
# 0                298              1632
# 1                 31               151
# 2                 16                84
# 3                 14                49
# 4                143               652
# ..               ...               ...
# 194                0                21
# 195                0               213
# 196               21               260
# 197               10                95
# 198               56               218
#
# [199 rows x 2 columns]

# %%
cant_hab.sum()
# Out:
# 4_6_years_total      4454
# 6_14_years_total    21156
# dtype: int64

# %% [markdown]
# # Filtrar la cantidad de habitante de 4 a 6 años en el distrito de trujillo

# %%
distrito_trujillo = la_libertad.loc[la_libertad['District'] == 'TRUJILLO']
cant_4_6=distrito_trujillo[['District','4_6_years_total']]
cant_4_6
# Out:
#    District  4_6_years_total
# 0  TRUJILLO              298
# 1  TRUJILLO               31
# 2  TRUJILLO               16
# 3  TRUJILLO               14

# %% [markdown]
# # Localizar la region de mayor cantidad de habitantes tanto para personas de 4 a 6 años como de 6 a 14 años

# %%
la_libertad.iloc[0]
# Out:
# Region                      LA LIBERTAD
# District                       TRUJILLO
# Place                        P.TRUJILLO
# 4_6_years_men                       162
# 4_6_years_women                     136
# 4_6_years_total                     298
# 6_14_years_men                      823
# 6_14_years_women                    809
# 6_14_years_total                   1632
# man_read                            580
# women_read                          589
# total_read                         1169
# men_not_read                        405
# women_not_read                      356
# total_not_read                      761
# man_write                           398
# women_write                         402
# total_write                         800
# men_not_write                       587
# women_not_write                     543
# total_not_write                    1130
# instruction_men                     543
# instruction_women                   495
# ...
